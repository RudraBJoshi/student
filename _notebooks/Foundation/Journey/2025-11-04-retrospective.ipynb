# %% [markdown]
# ---
# title: Trimester One Retrospective
# description: Encompassing what I have learned in Trimenster 1
# comments: false
# layout: default
# permalink: /github/pages/retrospective
# ---

# %% [markdown]
# # The Journey of CSP: Start to West Coast

# %% [markdown]
# 1. Remember key things from 3 sprints (Tools, Fundamentals of JavaScript/Python,  West Coast Travel or Digital Famine.
# 2. How N@tM went?  Did you get a comment or two you liked?
# 3. What do you want to do next on project, given time?
# 4. What do you want to learn next in CompSci?
# 5. Analytics review.
# 6. MCQ review, score, correction, and approach
# 7. Something cool you'd like to share.
#
#
# The key things I learned in all 3 sprints is how to code in python and make applications to present to others. I learned how to use tools and run make so can see my website on local host. N@TM went great. I showed many parents how LLM Memory works and they seem so enjoy how we presented it with demos and a mini interactive quiz. I even got to show my dad who said that I did a really good job explaining what a context window is. Given time, another project I want to do is to learn how to make an AI from the ground up with our own neural net and training phases. In CompSci specifically I want to experiment less with relational databases and transition into more mainstream NoSQLs like MongoDB or use other search algorithms like vector searching. Looking at my analytics, I made 41 commits, 3 pull requests, made 4 issues, and changed 3114 lines of code.
